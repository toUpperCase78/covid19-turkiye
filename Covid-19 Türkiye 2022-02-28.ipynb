# %% [markdown]
# # **KORONAVİRÜS (COVID-19) SALGINI**
#
# # **TÜRKİYE'NİN DURUMU HAKKINDA VERİ ANALİZİ**
#
# ## SAYI: 46  (28 Şubat 2022)
#
# ### HAZIRLAYAN: Doğan Yiğit Yenigün (toUpperCase78)
#
# **Her güne ait tüm sayısal veriler, Türkiye'de ilk vakanın görüldüğü 11 Mart 2020'den beri T. C. Sağlık Bakanlığı Covid-19 Bilgilendirme Sayfası'nda günlük olarak yayımlanan "Türkiye Günlük Covid-19 Tablosu"ndan alınmaktadır.**
#
# ### KAYNAK: [covid19.saglik.gov.tr](https://covid19.saglik.gov.tr/)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
covid19TR = pd.read_csv('covid_19_Turkiye_2022_02_28.csv')

# %%
covid19TR = covid19TR.set_index('Tarih')
covid19TR['Toplam Test'] = covid19TR['Toplam Test'].fillna(0).astype(int)
covid19TR['Günlük Vaka'] = covid19TR['Günlük Vaka'].fillna(0).astype(int)
covid19TR['Toplam Vaka'] = covid19TR['Toplam Vaka'].fillna(0).astype(int)
covid19TR['1. Doz Ort(%)'] = covid19TR['1. Doz Ort(%)'].fillna(0)
covid19TR['2. Doz Ort(%)'] = covid19TR['2. Doz Ort(%)'].fillna(0)
covid19TR['1. Doz Toplam'] = covid19TR['1. Doz Toplam'].fillna(0).astype(int)
covid19TR['2. Doz Toplam'] = covid19TR['2. Doz Toplam'].fillna(0).astype(int)
covid19TR['3. Doz Toplam'] = covid19TR['3. Doz Toplam'].fillna(0).astype(int)
covid19TR['Test Artış'] = covid19TR['Toplam Test'].diff().fillna(0).astype(int)
covid19TR['Vefat Artış'] = covid19TR['Toplam Vefat'].diff().fillna(0).astype(int)
covid19TR['İyileşen Artış'] = covid19TR['Toplam İyileşen'].diff().fillna(0).astype(int)
covid19TR['Vefat +/-'] = covid19TR['Vefat Artış'].diff().fillna(0).astype(int)
covid19TR['Test +/-'] = covid19TR['Test Artış'].diff().fillna(0).astype(int)
covid19TR['Vaka +/-'] = covid19TR['Günlük Vaka'].diff().fillna(0).astype(int)
covid19TR['İyileşen +/-'] = covid19TR['İyileşen Artış'].diff().fillna(0).astype(int)

# %%
ind = 274
while covid19TR.iloc[ind,8] != 0:
    covid19TR.iloc[ind-1,9] = covid19TR.iloc[ind,9] - covid19TR.iloc[ind,8]
    ind -= 1

# %% [markdown]
# ## **Son 20 Güne Dair Sayısal Bilgiler**

# %%
covid19TR[['Toplam Test', 'Günlük Vaka', 'Toplam Vaka', 'Toplam Vefat', 'Toplam İyileşen',
           '1. Doz Ort(%)', '2. Doz Ort(%)', '1. Doz Toplam', '2. Doz Toplam', '3. Doz Toplam']].tail(20)
# Out:
#             Toplam Test  Günlük Vaka  Toplam Vaka  Toplam Vefat  \
# Tarih
# 2022-02-09    135647434       108563     12554674         89477
# 2022-02-10    136097478        98602     12653276         89741
# 2022-02-11    136555620        95065     12748341         89994
# 2022-02-12    137003967        86193     12834534         90266
# 2022-02-13    137423523        73787     12908321         90542
# 2022-02-14    137862076        76632     12984953         90808
# 2022-02-15    138324031        94730     13079683         91117
# 2022-02-16    138787272        94716     13173859         91388
# 2022-02-17    139252835        92406     13266265         91646
# 2022-02-18    139716690        87411     13353676         91910
# 2022-02-19    140178942        80454     13434130         92188
# 2022-02-20    140619125        70355     13504485         92451
# 2022-02-21    141080638        85026     13589511         92719
# 2022-02-22    141543973        86070     13675581         92990
# 2022-02-23    142008058        86600     13762181         93258
# 2022-02-24    142463259        79708     13841889         93539
# 2022-02-25    142917206        71736     13913626         93805
# 2022-02-26    143339061        61764     13975390         94026
# 2022-02-27    143733324        49792     14025182         94232
# 2022-02-28    144143759        64275     14089457         94445
#
#             Toplam İyileşen  1. Doz Ort(%)  2. Doz Ort(%)  1. Doz Toplam  \
# Tarih
# 2022-02-09         11668035          92.68          84.69       57528865
# 2022-02-10         11755967          92.70          84.72       57540072
# 2022-02-11         11841725          92.72          84.75       57553305
# 2022-02-12         11915251          92.73          84.77       57559910
# 2022-02-13         11985420          92.74          84.78       57564527
# 2022-02-14         12060356          92.76          84.81       57576058
# 2022-02-15         12163029          92.78          84.83       57586821
# 2022-02-16         12267438          92.79          84.86       57596845
# 2022-02-17         12371426          92.81          84.88       57605406
# 2022-02-18         12473520          92.82          84.91       57614902
# 2022-02-19         12570184          92.83          84.92       57619810
# 2022-02-20         12661348          92.84          84.93       57623451
# 2022-02-21         12755750          92.85          84.96       57634087
# 2022-02-22         12853949          92.87          84.98       57643606
# 2022-02-23         12949475          92.88          85.00       57652077
# 2022-02-24         13043888          92.89          85.02       57659736
# 2022-02-25         13134005          92.91          85.04       57668314
# 2022-02-26         13219557          92.91          85.05       57672341
# 2022-02-27         13289402          92.92          85.06       57675034
# 2022-02-28         13366234          92.93          85.08       57682903
#
#             2. Doz Toplam  3. Doz Toplam
# Tarih
# 2022-02-09       52566932       25886830
# 2022-02-10       52585057       25978778
# 2022-02-11       52606514       26092490
# 2022-02-12       52616197       26154677
# 2022-02-13       52623391       26198141
# 2022-02-14       52640859       26286722
# 2022-02-15       52657210       26369364
# 2022-02-16       52672756       26450661
# 2022-02-17       52685959       26519073
# 2022-02-18       52701325       26594120
# 2022-02-19       52709583       26638894
# 2022-02-20       52715583       26671610
# 2022-02-21       52732078       26749144
# 2022-02-22       52746699       26817259
# 2022-02-23       52760079       26878969
# 2022-02-24       52771929       26933128
# 2022-02-25       52786023       26993218
# 2022-02-26       52792845       27023539
# 2022-02-27       52797530       27044968
# 2022-02-28       52809698       27091808

# %% [markdown]
# **NOT 1:** 29 Temmuz 2020'den itibaren _Toplam Yoğun Bakım Sayısı_ ve _Toplam Entübe Hasta Sayısı_ yerine _Hastalarda Zatürre Oranı_ ve _Ağır Hasta Sayısı_ paylaşılmaya başlanmıştır. Buradaki _Ağır Hasta Sayısı,_ oksijen saturasyonu belli oranın altında veya yoğun bakım gerektiren hastalar için uluslararası tanımlamaya uygun olarak belirlenmektedir. **Ancak 4 Temmuz 2021 tarihi itibarıyla bu verilerin paylaşımı durdurulmuştur!**
#
# **NOT 2:** 25 Kasım 2020'den itibaren hasta sayısı üzerine semptomsuz olduğu halde PCR testi pozitif çıkanların da dahil edildiği _Günlük Vaka_ sayısı paylaşılmaya başlanmıştır.
#
# **NOT 3:** Bu tablodaki _Toplam Hasta Sayısı,_ 10 Aralık 2020'den sonra Covid-19 Bilgilendirme Sayfası Günlük Tablosu'nda görünmemesine rağmen halen görünür olan _Günlük Hasta Sayısı_ sonraki günlerin üzerine eklenerek hesaplanmaktadır.
#
# **NOT 4:** 10 Aralık 2020'den itibaren paylaşılan _Toplam Vaka_ sayısı, PCR testi pozitif çıkan tüm kişilerin toplamını göstermektedir.
#
# **NOT 5:** 10 Aralık 2020'den önceki _Toplam Vaka Sayısı,_ mevcut gündeki toplam vaka sayısının günlük vaka sayısı ile farkı alınarak hesaplanmıştır (Günlük Vaka sayısının ilk açıklandığı 25 Kasım 2020'ye doğru geriye dönük gidilerek; yani elde edilen veri 24 Kasım 2020'ye kadardır).
#
# **NOT 6:** _Toplam İyileşen_ sayısı, 12 Aralık 2020'den itibaren iyileşen hastalara ilaveten izolasyon süresi dolan vakaları da dahil etmektedir.
#
# **NOT 7:** 4 Temmuz 2021'den itibaren gösterilen yeni günlük tablo ile _en az bir doz aşı olmuş 18 yaş ve üstü nüfusun 1. doz ve 2. doz Türkiye ortalaması yüzdesi_ ve _1. doz, 2. doz ve 3. doz aşı uygulaması toplamı_ gösterilmeye başlanmıştır.
#
# **NOT 8:** Tüm sayıların tutulduğu veri setinin özelliklerinin yapısı gereği yukarıdaki tabloda genelde toplamlar verilmiş olmasına karşın aşağıdaki analizlerde günlük sayılara dair veriler görülebilmektedir.

# %% [markdown]
# ## **Covid-19 Salgınının Başından Beri Türkiye'nin Durumu**

# %%
plt.style.use('seaborn')
plt.figure(figsize=(13.5,12), facecolor='white')
plt.rcParams['axes.facecolor'] = '#ffffff'
plt.rcParams['axes.edgecolor'] = '#eeeeee'
toplam_test = covid19TR['Toplam Test']
toplam_hasta = covid19TR['Toplam Hasta']
toplam_vaka = covid19TR['Toplam Vaka'][258:]
toplam_iyilesen_12ara2020_once = covid19TR['Toplam İyileşen'][:276]
toplam_iyilesen_12ara2020_sonra = covid19TR['Toplam İyileşen'][276:]
toplam_vefat = covid19TR['Toplam Vefat']
toplam_gun = len(covid19TR)
gunler = [0, 21, 51, 82, 112, 143, 174, 204, 235, 265, 296, 327, 355, 386, 416, 447, 477, 508, 539, 569, 600, 630, 661, 692,
          len(covid19TR)-1]
def plot_olustur(veri, y_min):
    plt.axis([-2, len(covid19TR)+2, y_min, max(veri)*1.07])
    plt.axhline(0, color='k', linewidth=1)
    plt.axvline(len(covid19TR)-1, color='k', linewidth=1.5)
    plt.axvline(365, color='b', linewidth=1.5)
    plt.yticks(fontsize=13)
    plt.grid(visible=True, color='#cfcfcf')  
def veri_cizdir(veri, plot_renk, alt_renk, etiket, baslangic = 0, bitis = toplam_gun):
    plt.plot(range(baslangic, bitis), veri, linewidth=3, color=plot_renk, label=etiket)
    plt.fill_between(range(baslangic, bitis), veri, color=alt_renk, alpha=0.2)
    plt.legend(loc='upper left', fontsize=15)
def sayi_yazdir(x_pos, y_pos, sayi, renk, boyut=15):
    plt.text(x_pos, y_pos, sayi, color=renk, fontsize=boyut)
    
plt.subplot(4, 1, 1)
plot_olustur(toplam_test, -350000)
veri_cizdir(toplam_test, 'orange', 'orange', 'Test')
sayi_yazdir(toplam_gun+0.4, toplam_test[-1]*0.95, toplam_test[-1], '#e09112', 18)
plt.title('Covid-19 Salgınının Başından Beri Türkiye\'nin Durumu', fontsize=24, fontweight='bold')
plt.xticks(gunler, [' ' for _ in range(len(gunler))])
plt.subplot(4, 1, 2)
plot_olustur(toplam_vaka, -110000)
veri_cizdir(toplam_vaka, '#bb0000', '#bb0000', 'Vaka (24 Kasım 2020 ve Sonrası)', 258)
sayi_yazdir(toplam_gun+0.4, toplam_vaka[-1]*0.95, toplam_vaka[-1], '#bb0000', 18)
sayi_yazdir(207, toplam_vaka[0]-200000, toplam_vaka[0], '#bb0000')
plt.xticks(gunler, [' ' for _ in range(len(gunler))])
plt.subplot(4, 1, 3)
plot_olustur(toplam_iyilesen_12ara2020_sonra, -90000)
veri_cizdir(toplam_iyilesen_12ara2020_once, '#007700', '#007700', 'İyileşen (12 Aralık 2020\'den önce)', 0, 276)
veri_cizdir(toplam_iyilesen_12ara2020_sonra, '#00bb00', '#00bb00', 'İyileşen (12 Aralık 2020 ve Sonrası)', 276)
sayi_yazdir(225, toplam_iyilesen_12ara2020_sonra[0]+300000, toplam_iyilesen_12ara2020_sonra[0], '#009900')
sayi_yazdir(230, toplam_iyilesen_12ara2020_once[-1]+250000, toplam_iyilesen_12ara2020_once[-1], '#007700')
sayi_yazdir(toplam_gun+0.5, toplam_iyilesen_12ara2020_sonra[-1]*0.95, toplam_iyilesen_12ara2020_sonra[-1], '#009900', 18)
plt.xticks(gunler, [' ' for _ in range(len(gunler))])
plt.subplot(4, 1, 4)
plot_olustur(toplam_vefat, -700)
veri_cizdir(toplam_vefat, '#888888', '#777777', 'Vefat')
sayi_yazdir(toplam_gun+0.4, toplam_vefat[-1]*0.95, toplam_vefat[-1], '#777777', 18)
plt.xlabel('Tarih', fontsize=16)
plt.xticks(gunler, covid19TR.index[gunler], fontsize=12, rotation=75)
plt.tight_layout()
plt.show()

# %% [markdown]
# _Yukarıdaki grafiklerde bulunan koyu mavi dik çizgiler, 11 Mart 2021 tarihini yani ilk vakanın üzerinden geçen bir yılı işaret etmektedir._

# %% [markdown]
# ### **Türkiye'de yaklaşık iki yıl süreyle devam eden Koronavirüs ile mücadelesinde yukarıdaki grafiklere bakıldığında;**
#
# TOPLAM TEST SAYISININ en baştan itibaren eğimin **üstel** gibi bir hal aldığı ve sonrasında **son on ayda sabit denilebilecek şekilde** yükselişini sürdürerek **143 milyonu geçtiğini** görmekteyiz.
#
# TOPLAM VAKA SAYILARI (**NOT 5**'e bakınız) **Aralık 2020'nin ikinci yarısına** kadar sabit bir şekilde artmış, sonrasında **giderek yavaşlamış**; **Mart 2021'in ikinci yarısından sonra** eğimin yeniden büyük ölçüde yükselmiş ama **tam kapanmanın** sonrasında son bir ay içinde artış **önemli ölçüde** azalmış, sonrasında son **altı-yedi ayda** yeniden  yükselişini sürdürmüş ve özellikle **son iki ayda Omicron varyantının** da etkisiyle tırmanışa geçerek **14 milyonu** geçmiştir!
#
# TOPLAM İYİLEŞEN SAYISI, _12 Aralık 2020_ tarihine kadar yaklaşık **460 bin** kadar idi. Bu tarihten sonra **izolasyon süresi dolan vakalar**ın da dahil edilmesiyle (yukarıdaki **NOT 6**'ya bakınız) sayıda bir anda sıçrama yaşanmış _(1 milyonun üzerinde)_ ve grafiğe göre **2020'nin sonlarına doğru sabit** şekilde yükselmiş, sonrasında yavaşlamış, devamında **Mart 2021'in yarısına kadar aynı seyirde** devam etmiş ve **Mayıs 2021'in ikinci yarısına kadar** hızlı artış yaşanmış, bundan sonrasında eğimin **daha yatay** seviyede sürmesi, devamında **son altı aydaki artış eğilimi** ve **özellikle son bir buçuk ayda daha da yüksek olması ile 13.2 milyonu** aşmıştır!
#
# TOPLAM VEFAT SAYISINDAKİ eğim için başlarda, **Nisan 2020 içinde** yüksek seyretmiş, **Mayıs 2020'den sonra** yavaşlamış, ama **Eylül 2020'den itibaren** yine giderek yükselmiş ve bu eğim **Kasım 2020'nin ikinci yarısından sonra** artmaya devam etmiştir! **2021'in başından itibaren giderek yavaşlasa** da özellikle **Mart 2021'in ikinci yarısından sonra** yeniden yükselişe geçmiştir. **Tam kapanmadan** sonra **yeniden yatay seyirde olduğu** görülse de **son yedi ay** içinde **neredeyse aynı hızda yükselişte bulunarak 94 bin**'i geçmiştir!

# %% [markdown]
# ## Covid-19 - Türkiye'de Aşılamanın Durumu

# %%
birinci_doz_ort = covid19TR['1. Doz Ort(%)'][480:]
ikinci_doz_ort = covid19TR['2. Doz Ort(%)'][480:]
birinci_doz_toplam = covid19TR['1. Doz Toplam'][480:]
ikinci_doz_toplam = covid19TR['2. Doz Toplam'][480:]
ucuncu_doz_toplam = covid19TR['3. Doz Toplam'][480:]
gunler = [0] + list(range(8,len(birinci_doz_ort),7))
plt.figure(figsize=(13.5,10))
plt.subplot(2,1,1)
plt.axis([-0.2, len(birinci_doz_ort)-0.2, 20, max(birinci_doz_ort)+3])
plt.axhline(20, color='k')
plt.plot(birinci_doz_ort, color='#b38459', linewidth=3, label='1. Doz Ortalama (%)')
plt.fill_between(range(0, len(birinci_doz_ort)), birinci_doz_ort, color='#b38459', alpha=0.2)
plt.text(0.1, birinci_doz_ort[0]-3.5, birinci_doz_ort[0], color='#b38459', fontsize=16)
plt.text(len(birinci_doz_ort)-0.15, birinci_doz_ort[-1]-1, birinci_doz_ort[-1], color='#b38459', fontsize=18)
plt.plot(ikinci_doz_ort, color='#7d5d3e', linewidth=3, label='2. Doz Ortalama (%)')
plt.fill_between(range(0, len(ikinci_doz_ort)), ikinci_doz_ort, color='#7d5d3e', alpha=0.2)
plt.text(len(ikinci_doz_ort)-0.15, ikinci_doz_ort[-1]-1, ikinci_doz_ort[-1], color='#7d5d3e', fontsize=18)
plt.text(0.1, ikinci_doz_ort[0]-3.5, ikinci_doz_ort[0], color='#7d5d3e', fontsize=16)
plt.axvline(len(birinci_doz_ort)-1, linewidth=5, color='k', alpha=0.5)
plt.title('Covid-19 - Türkiye\'de Aşılamanın Durumu', fontsize=24, fontweight='bold')
plt.ylabel('Aşı Oranı (%)', fontsize=16, fontweight='bold')
plt.xticks(gunler, ['' for _ in range(len(gunler))])
plt.yticks(fontsize=14)
plt.legend(fontsize=14)
plt.grid(visible=True, color='#cfcfcf')
plt.subplot(2,1,2)
plt.axis([-0.2, len(birinci_doz_toplam)-0.2, 0, birinci_doz_toplam.max()*1.1])
plt.plot(birinci_doz_toplam, color='#8dc9c8', linewidth=3, label='1. Doz Toplam')
plt.fill_between(range(0, len(birinci_doz_toplam)), birinci_doz_toplam, color='#8dc9c8', alpha=0.2)
plt.text(len(birinci_doz_toplam)-0.15, birinci_doz_toplam[-1]-800000, birinci_doz_toplam[-1], color='#7db9b8', fontsize=18)
plt.text(0.1, birinci_doz_toplam[0]-2500000, birinci_doz_toplam[0], color='#7db9b8', fontsize=15)
plt.plot(ikinci_doz_toplam, color='#72a3a2', linewidth=3, label='2. Doz Toplam')
plt.fill_between(range(0, len(ikinci_doz_toplam)), ikinci_doz_toplam, color='#72a3a2', alpha=0.2)
plt.text(len(ikinci_doz_toplam)-0.15, ikinci_doz_toplam[-1]-800000, ikinci_doz_toplam[-1], color='#629392', fontsize=18)
plt.text(0.1, ikinci_doz_toplam[0]-2500000, ikinci_doz_toplam[0], color='#629392', fontsize=15)
plt.plot(ucuncu_doz_toplam, color='#5f8786', linewidth=3, label='3. Doz Toplam')
plt.fill_between(range(0, len(ucuncu_doz_toplam)), ucuncu_doz_toplam, color='#5f8786', alpha=0.2)
plt.text(len(ucuncu_doz_toplam)-0.15, ucuncu_doz_toplam[-1]-800000, ucuncu_doz_toplam[-1], color='#4f7776', fontsize=18)
plt.text(0.1, ucuncu_doz_toplam[0]+3500000, ucuncu_doz_toplam[0], color='#4f7776', fontsize=15)
plt.axvline(len(birinci_doz_toplam)-1, linewidth=5, color='k', alpha=0.5)
plt.axhline(0, color='k')
plt.xlabel('Tarih', fontsize=16)
plt.ylabel('Toplam Uygulanan Doz', fontsize=16, fontweight='bold')
plt.xticks(gunler, birinci_doz_ort.index[gunler], fontsize=12, rotation=75)
plt.yticks(fontsize=13)
plt.legend(fontsize=14)
plt.grid(visible=True, color='#cfcfcf')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Yukarıda görülen ilgili oranlar ve sayılar, en az bir doz aşı olmuş 18 yaş ve üstü nüfusu kapsamaktadır.**
#
# _4 Temmuz 2021 - 28 Şubat 2022 tarihleri arasındaki aşı oranlarını ve toplam uygulanan dozları incelediğimizde;_
#
# * Birinci doz ortalamasının **%57.81**'den **%92.93**'e; ikinci doz ortalamasının da **%25.23**'ten **%85.08**'e yükseldiğini görmekteyiz.
# * Toplam uygulanan doz sayıları için grafikte yazılanlara ilaveten, ilk açıklanan günden bugüne 1. dozda **21 milyon 799 bin 305**, 2. dozda **37 milyon 150 bin 87** ve 3. dozda ise **26 milyon 27 bin 282** doz artış kaydedilmiştir.
# * Özellikle 3. doz toplam uygulama sayısında Aralık 2021'in ikinci yarısından itibaren ikinci doz **Biontech** aşısının ardından 3 ay geçmiş olan kişilerin üçüncü dozu olabilmesiyle birlikte **büyük hızda artışın olması** dikkat çekmektedir! Ancak **Ocak 2022'nin iknici yarısından sonra** üçüncü doz sayısındaki artış giderek yavaşlamıştır ve son haftalarda diğer doz toplamlarına görülen toplam doz artış hızına yaklaşmıştır.

# %% [markdown]
# ## Covid-19 - Türkiye'de Son 20 Güne Ait Aşılama Grafiği

# %%
birinci_doz_son20gun = covid19TR['1. Doz Toplam'][-21:].diff()
ikinci_doz_son20gun = covid19TR['2. Doz Toplam'][-21:].diff()
ucuncu_doz_son20gun = covid19TR['3. Doz Toplam'][-21:].diff()
plt.figure(figsize=(15,8))
plt.xlim([0.5, 19.5])
plt.axis([-0.2, 19.2, birinci_doz_son20gun.min()*0.5, ucuncu_doz_son20gun.max()*1.06])
plt.title('Covid-19 - Türkiye\'de Son 20 Güne Ait Aşılama Grafiği', fontsize=24, fontweight='bold')
plt.plot(birinci_doz_son20gun[1:], color='#8dc9c8', linewidth=5, marker='o', markersize=12, label='1. Doz Günlük')
plt.text(19.2, birinci_doz_son20gun[-1]-1500, int(birinci_doz_son20gun[-1]), fontsize=18, color='#8dc9c8')
plt.plot(ikinci_doz_son20gun[1:], color='#72a3a2', linewidth=5, marker='o', markersize=12, label='2. Doz Günlük')
plt.text(19.2, ikinci_doz_son20gun[-1]-200, int(ikinci_doz_son20gun[-1]), fontsize=18, color='#72a3a2')
plt.plot(ucuncu_doz_son20gun[1:], color='#5f8786', linewidth=5, marker='o', markersize=12, label='3. Doz Günlük')
plt.text(19.2, ucuncu_doz_son20gun[-1]-1000, int(ucuncu_doz_son20gun[-1]), fontsize=18, color='#4f7776')
plt.xticks(rotation=75, fontsize=12)
plt.yticks(fontsize=14)
plt.grid(visible=True, color='#cfcfcf')
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# Türkiye'de son 20 güne ait aşılama sayılarına baktığımızda, 1. dozun günlük aşılama sayılarının 2. dozun günlük aşılama sayılarına kıyasla **önceki veri analizlerine benzer şekilde her zaman gerisinde kaldığı** açıkça görülmektedir. Başka bir deyişle, 2. doz günlük aşı sayılarının yukarıdaki ilk grafiğe göre **daha yüksek seyretmesi** ile toplam sayıda 1. doza yavaş da olsa hâlâ yaklaşmakta olduğunu ifade edebiliriz; yine ilginçtir ki günlük 1. ile 2. doz sayıları **hemen hemen aynı oranda** birbirlerini seyretmektedirler.
#
# Üçüncü doz günlük aşı sayılarında ise 2. doz **Biontech** aşısının üzerinden 3 aydan fazla zaman geçen kişiler için 3. dozu olabilme imkanının getirilmesinden sonra **Aralık 2021'in ikinci yarısından** itibaren **daha hızlı yükselişe** rastlanılmıştır ki günlük 1. ile 2. doza kıyasla **oldukça yüksek** çıktığını açıkça görmekteyiz. Lakin önceki günlere nazaran bu farkın **azaldığını** da belirtmeliyiz.

# %% [markdown]
# ## Covid-19 - Tüm Günler Vaka, Vefat & İyileşen Artış Sayıları & Gelecek İçin Tahminler

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
vaka_artis = covid19TR['Günlük Vaka'][259:]
vefat_artis = covid19TR['Vefat Artış']
iyilesen_artis_12ara2020_once = covid19TR['İyileşen Artış'][:276]
iyilesen_artis_12ara2020_sonra = covid19TR['İyileşen Artış'][277:]
gun_cizgiler = np.array([g for g in range(29,len(covid19TR)-1,30)])
gun_cizgiler = np.insert(gun_cizgiler, 0, 0)
gun_cizgiler = np.append(gun_cizgiler, len(covid19TR)-1)
gun_araliklar = [30, 90, 180]
renk=['orange', '#23588d', '#a375a4']

y_ileri_tahminler = []
polynomial = PolynomialFeatures(degree=2)
linear = LinearRegression()
for s in range(1,4):
    y_ileri_tahmin = []
    for g in gun_araliklar:
        if s == 1:     y = vaka_artis.fillna(0).values[-g:].reshape(-1,1)
        elif s == 2:   y = iyilesen_artis_12ara2020_sonra.values[-g:].reshape(-1,1)
        elif s == 3:   y = vefat_artis.values[-g:].reshape(-1,1)
        x = np.array(list(range(len(y)))).reshape(-1,1)
        x_test = np.array(list(range(len(y), len(y)+60))).reshape(-1,1)
        x_poly = polynomial.fit_transform(x)
        x_test_poly = polynomial.fit_transform(x_test)
        linear.fit(x_poly, y)
        y_ileri_tahmin.append(linear.predict(x_test_poly))
    y_ileri_tahminler.append(y_ileri_tahmin)
    
y_mevcut_tahminler = []
polynomial = PolynomialFeatures(degree=6)
for s in range(1,5): 
    if s == 1:    y = vaka_artis.fillna(0).values.reshape(-1,1)
    elif s == 2:  y = iyilesen_artis_12ara2020_once.fillna(0).values.reshape(-1,1)
    elif s == 3:  y = iyilesen_artis_12ara2020_sonra.fillna(0).values.reshape(-1,1)
    elif s == 4:  y = vefat_artis.fillna(0).values.reshape(-1,1)
    x = np.array(list(range(len(y)))).reshape(-1,1)
    x_poly = polynomial.fit_transform(x)
    linear.fit(x_poly, y)
    y_mevcut_tahminler.append(linear.predict(x_poly))
    
def plot_cizdir(veri, y_alt, y_ust, y_etiket, x_tick, x_tick_metin):
    plt.axis([-2, len(covid19TR)+65, y_alt, veri.max()+y_ust])
    plt.axvline(x=len(covid19TR)-1, color='k', linewidth=4, alpha=0.5)
    plt.axhline(0, color='k', linewidth=1)
    plt.yticks(fontsize=13)
    plt.ylabel(y_etiket, fontsize=14, fontweight='bold')
    plt.xticks(x_tick, x_tick_metin, fontsize=13, rotation=60)
    plt.grid(visible=True, color='#c0c0c0')
    plt.legend(loc='upper left', fontsize=13)  
def veri_cizdir(veri, baslangic, bitis, renk, kalinlik=1, alpha=1, etiket=None):
    plt.plot(range(baslangic, bitis), veri, color=renk, linewidth=kalinlik, alpha=alpha, label=etiket) 
def tahmin_cizdir(veri, gunler, renk, etiket, kalinlik=1):
    plt.plot(gunler, veri, color=renk, label=etiket, linewidth=kalinlik)
def alan_doldur(veri, baslangic, bitis, renk, alpha):
    plt.fill_between(range(baslangic, bitis), veri, color=renk, alpha=alpha)
def cizgi_yerlestir(pozisyon, renk, alpha, kalinlik):
    plt.axvline(x=pozisyon, color=renk, alpha=alpha, linewidth=kalinlik)
    
plt.figure(figsize=(15.5,12.5))
plt.subplot(3,1,1)
plt.title('Covid-19 - Türkiye\'de Vaka, Vefat & İyileşen Günlük Artış Sayıları ve Gelecek İçin Tahminler', 
          fontsize=19, fontweight='bold')
veri_cizdir(vaka_artis, 259, len(covid19TR), '#bb0000', 2, 1, 'Vaka Artış')
veri_cizdir(y_mevcut_tahminler[0], 259, len(covid19TR), '#bb0000')
alan_doldur(vaka_artis, 259, len(covid19TR), '#bb0000', 0.2)
cizgi_yerlestir(259, '#bb0000', 0.7, 4)
for i in range(len(gun_araliklar)):
    tahmin_cizdir(y_ileri_tahminler[0][i], x_test+len(covid19TR)-180, renk[i], 
                  'Tahmin (Son ' + str(gun_araliklar[i]) + ' Güne Göre)', 4)
    cizgi_yerlestir(len(covid19TR)-gun_araliklar[i], renk[i], 0.8, 2)
plot_cizdir(vaka_artis, -500, 15000, 'Günlük Vaka Artışı', gun_cizgiler, 
            ['' for _ in range(len(gun_cizgiler))])
plt.subplot(3,1,2)
veri_cizdir(vefat_artis, 0, len(covid19TR), '#777777', 2, 1, 'Vefat Artış')
veri_cizdir(y_mevcut_tahminler[3], 0, len(covid19TR), '#555555', 2, 0.5)
alan_doldur(vefat_artis, 0, len(covid19TR), '#555555', 0.25)
for i in range(len(gun_araliklar)):
    tahmin_cizdir(y_ileri_tahminler[2][i], x_test+len(covid19TR)-180, renk[i],
                 'Tahmin (Son ' + str(gun_araliklar[i]) + ' Güne Göre)', 4)
    cizgi_yerlestir(len(covid19TR)-gun_araliklar[i], renk[i], 0.8, 2)
plot_cizdir(vefat_artis, -2, 20, 'Günlük Vefat Artışı', gun_cizgiler, ['' for _ in range(len(gun_cizgiler))])
plt.subplot(3,1,3)
veri_cizdir(iyilesen_artis_12ara2020_once, 0, len(iyilesen_artis_12ara2020_once), '#00aa00', 2, 1, 
            'İyileşen Artış (12 Aralık 2020 öncesi)')
veri_cizdir(y_mevcut_tahminler[1], 0, len(y_mevcut_tahminler[1]), '#007700', 2, 0.7)
veri_cizdir(iyilesen_artis_12ara2020_sonra, 276, len(iyilesen_artis_12ara2020_sonra)+276, '#007700', 2, 1,
            'İyileşen Artış (12 Aralık 2020 sonrası)')
veri_cizdir(y_mevcut_tahminler[2], 276, len(covid19TR)-1, '#008800', 2, 0.7)
alan_doldur(iyilesen_artis_12ara2020_once, 0, len(covid19TR[:276]), '#008800', 0.2)
alan_doldur(iyilesen_artis_12ara2020_sonra, 276, len(covid19TR)-1, '#005500', 0.2)
cizgi_yerlestir(275, 'g', 0.7, 4)
for i in range(len(gun_araliklar)):
    tahmin_cizdir(y_ileri_tahminler[1][i], x_test+len(covid19TR)-180, renk[i], 
                  'Tahmin (Son ' + str(gun_araliklar[i]) + ' Güne Göre)', 4)
    cizgi_yerlestir(len(covid19TR)-gun_araliklar[i], renk[i], 0.8, 2)
plot_cizdir(iyilesen_artis_12ara2020_sonra, -400, 15000, 'Günlük İyileşen Artışı', gun_cizgiler, gun_cizgiler+1)
plt.xlabel('Gün', fontsize=15, fontweight='bold')
plt.show()

# %% [markdown]
# _**ÖNEMLİ 1:** 12 Aralık 2020 gününe ait iyileşen artış sayısının 1 milyonun üzerinde çıkmasından dolayı tutarlılık açısından ilgili grafiğe dahil edilmemiştir!_
#
# _**ÖNEMLİ 2:** 4 Temmuz 2021'den itibaren gösterilmeye başlanan yeni Günlük Covid-19 Tablosu ile artık Hasta Sayısı verisi paylaşılmadığından ilgili grafik ve tahmin artık yer almamaktadır!_
#
# **_Makine öğrenmesi yardımıyla_ gelecekteki günler için;**
#
# * _VAKA_ sayısında mevcut gün aralıklarındaki veriler değerlendirildiğinde son 30 güne göre **çok hızlı düşüşlerin olacağı**, son 90 güne göre **düşüşün son 30 güne nazaran daha yavaş olacağı** ve son 180 güne göre de **yukarıya doğru** çıkacağı;
# * _VEFAT_ sayısında son 30 güne göre **aşağı yönde çok hızlı şekilde düşüş olacağı**, son 90 güne göre **yukarı yönde çok hızlı artışın olacağı** ve son 180 güne göre ise **sayının daha yavaş şekilde yükselişte olacağı**;
# * _İYİLEŞEN_ sayısında son 30 güne göre **çok yüksek seviyede düşüşün olacağı ve sıfırlanacağı**, son 90 ve 180 güne göre de **yüksek hızda artışın olacağı** tahmin edilmektedir!

# %% [markdown]
# ## Son 20 Gün İçindeki Günlük Vaka Sayıları

# %%
plt.figure(figsize=(15.5,6))
gunluk_vaka_son20 = covid19TR['Günlük Vaka'][-20:]
slp, intcp = np.polyfit(list(range(20)), gunluk_vaka_son20, 1)
plt.bar(covid19TR.index[-20:], gunluk_vaka_son20, color='#bb0000')
plt.axis([-0.5,19.5,gunluk_vaka_son20.min()*0.73,gunluk_vaka_son20.max()*1.08])
plt.xticks(covid19TR.index[-20:], rotation=80, fontsize=12, color='#550000')
plt.yticks(color='#770000', fontsize=14)
for i in range(len(covid19TR)-20,len(covid19TR)):
    plt.text(i-(len(covid19TR)-19.45), covid19TR.iloc[i,8]+1000, 
             "{:6}".format(int(covid19TR.iloc[i,8])), fontsize=14, color='#880000')
    plt.text(i-(len(covid19TR)-19.58), covid19TR.iloc[i,8]-3000, int(covid19TR.iloc[i,15]), fontsize=11, color='white')
    plt.text(i-(len(covid19TR)-19.60), covid19TR.iloc[i,8]-7500, 
            "{:5.2f}".format(covid19TR.iloc[i,8] / covid19TR.iloc[i,15] * 100), fontsize=14, color='white')
plt.plot([0, 19],[intcp, intcp+(slp*19)], color='#990000', linewidth=15, alpha=0.3)
plt.title('Covid-19 - Türkiye\'de Günlük Vaka Sayıları (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#770000', fontweight='bold')
plt.ylabel('Günlük Vaka Sayısı\nGünlük Test Sayısı ve Oranı (%)', fontsize=14, fontweight='bold', color='#770000')
plt.grid(visible=True, color='#ecbba8')
plt.show()

# %% [markdown]
# Son 20 günün vaka sayıları incelendiğinde, **Omicron varyantının etkisiyle** 2022 yılının başından itibaren **çok yüksek seyrettiği** bilinmektedir. Önceki haftalarda **100 binden yüksek** sayılarla karşışılırken, yukarıdaki grafiğe göre gitgide **sayıların azaldığı** açıkça görülmekte olup son günlerde **80 binin** altında kalmıştır.
#
# **400 binden** yüksek olan günlük test sayılarnı günlük vaka sayılarına oranladığımızda 17 Şubat 2022'den sonra **%20'nin altında** kalsa da hala bu oranlar yüksek seyretmektedir!

# %% [markdown]
# ## Son 20 Güne Dair Toplam Vaka Sayıları

# %%
plt.figure(figsize=(15.5,6))
toplam_vaka_son20 = covid19TR['Toplam Vaka'][-20:]
plt.axis([-0.8,19.5,min(toplam_vaka_son20)*0.97,max(toplam_vaka_son20)*1.02])
plt.plot(covid19TR.index[-20:], covid19TR['Toplam Vaka'][-20:], marker='s', markersize=15, linewidth=3, 
         linestyle='--', color='#bb0000')
for i in range(len(covid19TR)-20,len(covid19TR)):
    plt.text(i-len(covid19TR)+19.4, covid19TR.iloc[i,9]+75000, covid19TR.iloc[i,9], color='#bb0000', fontsize=11)
    plt.text(i-len(covid19TR)+19.7, covid19TR.iloc[i,9]-150000, "{:.2f}".format(covid19TR.iloc[i,9]/covid19TR.iloc[i,3]*100), 
             color="#bb0000", fontsize=14)
plt.title('Covid-19 - Türkiye\'de Toplam Vaka Sayıları (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#555555', fontweight='bold')
plt.xticks(covid19TR.index[-20:], rotation=70, fontsize=12, color='#555555')
plt.ylabel('Toplam Vaka Sayısı\nVaka Sayısı / Toplam Test Sayısı (%)', fontsize=16, color='#bb0000', fontweight='bold')
plt.yticks(fontsize=13, color='#bb0000')
plt.grid(visible=True, color='#dcbba8')
plt.show()

# %% [markdown]
# _Son 20 günün toplam vaka sayılarına_ dair grafiğe göre en son 28 Şubat 2022'de toplam vaka **14 milyon 89 bin 457** olarak gerçekleşmiştir.
#
# Bu sayıların toplam test sayılarına oranı, son 20 gün içinde **%9.26**'dan **%9.77**'ye yükseldiğini görmekteyiz!

# %% [markdown]
# ## Son 20 Günün Vaka Sayısı Değişim Grafiği

# %%
vaka_degisim = covid19TR['Vaka +/-'][-20:]
plt.figure(figsize=(15.5,5))
barc = []
for i in range(len(covid19TR)-20,len(covid19TR)):
    if covid19TR.iloc[i,20] >= 0:   barc.append('#cc0000')
    else:   barc.append('#00aa00')
plt.bar(covid19TR.index[-20:], vaka_degisim, color=barc)
plt.axis([-0.5,19.5,min(vaka_degisim)*1.3,max(vaka_degisim)*1.2])
plt.xticks(covid19TR.index[-20:], rotation=70, fontsize=12, color='#555555')
plt.yticks(color='#555555', fontsize=13)
for i in range(len(covid19TR)-20,len(covid19TR)):
    if covid19TR.iloc[i,20] >= 0:   c = '#880000'; vsh = 500;   hsh = 19.55
    elif covid19TR.iloc[i,20] < 0 and covid19TR.iloc[i,20] > -10000:
        c = '#008800'; vsh = -1800;   hsh = 19.6
    else:   c = '#008800'; vsh = -1800;   hsh = 19.5
    plt.text(i-(len(covid19TR)-hsh), covid19TR.iloc[i,20]+vsh, 
             "{:5}".format(int(covid19TR.iloc[i,20])), fontsize=14, color=c)
plt.axhline(0, color='black')
plt.title('Covid-19 - Türkiye\'de Vaka Sayısı Değişimi (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#555555', fontweight='bold')
plt.ylabel('Vaka Sayısı Değişim', fontsize=16, color='#555555', fontweight='bold')
plt.grid(visible=True, color='#cccccc')
plt.show()

# %% [markdown]
# Son 20 günün vaka sayısı değişimi incelendiğinde, en çok **18098** artış (15 Şubat 2022), ve en çok **12406** azalış (13 Şubat 2022) olmuştur.
#
# Bu değişimlerin **çoğunlukla aşağı yönde olduğunu** görmekteyiz!

# %% [markdown]
# ## **Son 20 Gün İçindeki Günlük Vefat Sayıları**

# %%
plt.figure(figsize=(15.5,6))
vefat_artis_son20 = covid19TR['Vefat Artış'][-20:]
slp, intcp = np.polyfit(list(range(20)), vefat_artis_son20, 1)
plt.bar(covid19TR.index[-20:], vefat_artis_son20, color='#777777')
plt.axis([-0.5,19.5,vefat_artis_son20.min()*0.95,vefat_artis_son20.max()*1.05])
plt.xticks(covid19TR.index[-20:], rotation=80, fontsize=12, color='#555555')
plt.yticks(color='#666666', fontsize=13)
for i in range(len(covid19TR)-20,len(covid19TR)):
    plt.text(i-(len(covid19TR)-19.67), covid19TR.iloc[i,16]+1, 
             "{:3}".format(int(covid19TR.iloc[i,16])), fontsize=17, color='#555555')
plt.plot([0, 19], [intcp, intcp+(slp*19)], color='#444444', linewidth=15, alpha=0.33)
plt.title('Covid-19 - Türkiye\'de Günlük Vefat Sayıları (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#555555', fontweight='bold')
plt.ylabel('Günlük Vefat Sayısı', fontsize=16, color='#666666', fontweight='bold')
plt.grid(visible=True, color='#cccccc')
plt.show()

# %% [markdown]
# Son 20 günün vefat sayılarına bakıldığında, önceleri **200'ün altında** açıklanan sayılar, artık **300'e yakın çıkabilmektedir** ve öyle ki 15 Şubat 2022'de **309** olarak açıklanmıştır! Yalnız **son üç gün** gözlü görülür şekilde azalma mevcuttur.
#
# Aşı olan kişi sayısının (her doz için) günden güne yükselmesine rağmen, vefat sayısında hâlâ **istenilen düzeye gelinememiş olması** düşündürücüdür!

# %% [markdown]
# ## **Son 20 Güne Dair Toplam Vefat Sayıları**

# %%
plt.figure(figsize=(15.5,6))
toplam_vefat_son20 = covid19TR['Toplam Vefat'][-20:]
plt.plot(covid19TR.index[-20:], toplam_vefat_son20, marker='d', markersize=15, linewidth=3, linestyle='--', color='#888888')
plt.xticks(covid19TR.index[-20:], rotation=70, fontsize=12, color='#555555')
plt.yticks(color='#666666', fontsize=13)
plt.axis([-0.5,19.5,min(toplam_vefat_son20)*0.989,max(toplam_vefat_son20)*1.01])
for i in range(len(covid19TR)-20,len(covid19TR)):
    plt.text(i-(len(covid19TR)-19.6), covid19TR.iloc[i,1]+300, covid19TR.iloc[i,1], fontsize=13, color='#555555')
    plt.text(i-(len(covid19TR)-19.65), covid19TR.iloc[i,1]-450, 
             "{:.3f}".format(covid19TR.iloc[i,1]/covid19TR.iloc[i,9]*100), fontsize=12, color='#666666')
plt.title('Covid-19 - Türkiye\'de Toplam Vefat Sayıları (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#666666', fontweight='bold')
plt.ylabel('Toplam Vefat Sayısı\nVefat Sayısı / Vaka Sayısı Oranları (%)', fontsize=14, color='#555555', fontweight='bold')
plt.grid(visible=True, color='#d0d0d0')
plt.show()

# %% [markdown]
# Toplam vefat sayısı son verilere göre **94 bin**'i geçmiştir!
#
# Toplam vaka sayısına göre oran, 9 Şubat 2022'de **%0.713** iken, ilerleyen günlerde gerilemeye devam ederek 28 Şubat 2022'de **%0.670**'ye kadar düşmüştür.

# %% [markdown]
# ## **Son 20 Günün Vefat Sayısı Değişim Grafiği**

# %%
vefat_degisim = covid19TR['Vefat +/-'][-20:]
plt.figure(figsize=(15.5,5))
barc = []
for i in range(len(covid19TR)-20,len(covid19TR)):
    if covid19TR.iloc[i,18] >= 0:
        barc.append('#cc0000')
    else:   barc.append('#00aa00')
plt.bar(covid19TR.index[-20:], vefat_degisim, color=barc)
plt.xticks(covid19TR.index[-20:], rotation=70, fontsize=12, color='#555555')
plt.yticks(color='#555555', fontsize=13)
plt.axis([-0.5, 19.5, min(vefat_degisim)*1.15, max(vefat_degisim)*1.25])
for i in range(len(covid19TR)-20,len(covid19TR)):
    if covid19TR.iloc[i,18] >= 10:    sh = 19.8;   vsh = 1.5;   c = '#880000'
    elif covid19TR.iloc[i,18] >= 0:   sh = 19.9;   vsh = 1.5;   c = '#880000'
    else:    sh = 19.8;    vsh = -5.2;   c = '#008800'
    plt.text(i-(len(covid19TR)-sh), covid19TR.iloc[i,18]+vsh, int(covid19TR.iloc[i,18]), fontsize=16, color=c)
plt.axhline(0, color='black')
plt.title('Covid-19 - Türkiye\'de Vefat Sayısı Değişimi (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#555555', fontweight='bold')
plt.ylabel('Vefat Sayısı Değişim', fontsize=16, color='#555555', fontweight='bold')
plt.grid(visible=True, color='#cccccc')
plt.show()

# %% [markdown]
# Yukarıdaki grafiğe göre vefat sayısı son 20 gün içinde, bir önceki güne kıyasla en fazla **43** yükselmiş (15 Şubat 2022) ve en fazla **45** azalmıştır (26 Şubat 2022). İkinci en büyük azalma da **38** ile 16 Şubat 2022'de görülmüştür.

# %% [markdown]
# ## **Son 20 Gün İçindeki Günlük İyileşen Sayıları**

# %%
plt.figure(figsize=(15.5,6))
index = covid19TR['İyileşen Artış'][-20:].index
iyilesen_artis = covid19TR['İyileşen Artış'][-20:]
gunluk_vaka = covid19TR['Günlük Vaka'][-20:]
slp, intcp = np.polyfit(list(range(20)), iyilesen_artis, 1)
plt.bar(index, iyilesen_artis, color='g', width=0.85)
plt.axis([-0.5,19.5,iyilesen_artis.min()*0.9,iyilesen_artis.max()*1.072])
plt.xticks(index, rotation=80, fontsize=12, color='#555555')
plt.yticks(color='g', fontsize=13)
for i in range(len(iyilesen_artis)):
    if iyilesen_artis[i] >= 100000:    sh = 0.6
    elif iyilesen_artis[i] >= 10000:   sh = 0.45
    else:    sh = 0.36
    plt.text(i-sh, iyilesen_artis[i]+500, int(iyilesen_artis[i]), fontsize=14, color='#006600')
    if abs(iyilesen_artis[i] - gunluk_vaka[i]) >= 10000:    sh = 0.4
    elif abs(iyilesen_artis[i] - gunluk_vaka[i]) >= 1000:   sh = 0.31
    elif abs(iyilesen_artis[i] - gunluk_vaka[i]) >= 100:    sh = 0.25
    else:    sh = 0.17
    plt.text(i-sh, iyilesen_artis[i]-2000, int(iyilesen_artis[i] - gunluk_vaka[i]), fontsize=12, color='white')
plt.plot([0, 19], [intcp, intcp+(slp*19)], color='#005500', linewidth=15, alpha=0.33)
plt.title('Covid-19 - Türkiye\'de Günlük İyileşen Sayıları (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#555555', fontweight='bold')
plt.ylabel('Günlük İyilşen Sayısı\nGünlük Vaka Sayısı ile Farkı', fontsize=16, color='#007700', fontweight='bold')
plt.grid(visible=True, color='#7cefac')
plt.show()

# %% [markdown]
# Son 20 günün iyileşen sayısının, yine önceki analizlerde görüldüğü gibi **düzensiz şekilde aşağı ve yukarı** yönlerde değiştiği, buna rağmen **hemen hemen her gün 70 binin üzerinde** açıklandığı görülmektedir. Bu günler içinde en yüksek sayı 16 Şubat 2022 tarihinde **104409**'dur.
#
# Yine grafiğe göre günlük iyileşen sayılarının günlük vaka sayılarına kıyasla, 14 Şubat 2022 tarihine kadar **daha düşük çıkarken**, bu tarihten sonra **hep daha yüksek çıkmıştır**. Artı yönde en büyük fark **23788** ile 26 Şubat 2022'de rastlanılmıştır.

# %% [markdown]
# ## **Son 20 Güne Dair Toplam İyileşen Sayıları**

# %%
plt.figure(figsize=(15.5,6))
toplam_iyilesen_son20 = covid19TR['Toplam İyileşen'][-20:]
plt.plot(covid19TR.index[-20:], toplam_iyilesen_son20, marker='^', markersize=15, linewidth=3, linestyle='--', color='g')
plt.xticks(covid19TR.index[-20:], rotation=70, fontsize=12, color='#555555')
plt.yticks(color='g', fontsize=13)
plt.axis([-0.5,19.5,min(toplam_iyilesen_son20)*0.98,max(toplam_iyilesen_son20)*1.02])
for i in range(len(covid19TR)-20,len(covid19TR)):
    plt.text(i-(len(covid19TR)-19.45), covid19TR.iloc[i,2]+80000, covid19TR.iloc[i,2], fontsize=11, color='#007700')
    plt.text(i-(len(covid19TR)-19.65), covid19TR.iloc[i,2]-150000, 
             "{:.2f}".format(covid19TR.iloc[i,2]/covid19TR.iloc[i,9]*100), fontsize=14, color='#007700')
plt.title('Covid-19 - Türkiye\'de Toplam İyileşen Sayıları (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#555555', fontweight='bold')
plt.ylabel('Toplam İyileşen Sayısı\nİyileşen Sayısı / Toplam Vaka Sayısı (%)', fontsize=16, color='#007700', fontweight='bold')
plt.grid(visible=True, color='#9cefac')
plt.show()

# %% [markdown]
# İyileşen sayısı toplamda **13.3 milyon**'u geçmiştir! Toplam vaka sayısına oranlara baktığımızda, 9 Şubat 2022'de **%92.94** iken, 28 Şubat 2022'de **%94.87**'ye kadar yükselmiştir.

# %% [markdown]
# ## **Son 20 Günün İyileşen Sayısı Değişim Grafiği**

# %%
iyilesen_degisim = covid19TR['İyileşen +/-'][-20:]
index = covid19TR['İyileşen +/-'][-20:].index
plt.figure(figsize=(15.5,5))
barc = []
for i in range(20):
    if iyilesen_degisim[i] >= 0:
        barc.append('#00aa00')
    else:   barc.append('#cc0000')
plt.bar(index, iyilesen_degisim, color=barc)
plt.xticks(index, rotation=70, fontsize=12, color='#555555')
plt.yticks(color='#555555', fontsize=13)
plt.axis([-0.5, 19.5, min(iyilesen_degisim)*1.2, max(iyilesen_degisim)*1.2])
for i in range(20):
    if iyilesen_degisim[i] >= 0:
        if int(iyilesen_degisim[i]) >= 10000:    sh = 0.46
        elif int(iyilesen_degisim[i]) >= 1000:   sh = 0.35
        elif int(iyilesen_degisim[i]) >= 100:    sh = 0.25
        else:    sh = 0.18
        plt.text(i-sh, iyilesen_degisim[i]+800, int(iyilesen_degisim[i]), fontsize=14, color='#008800')
    else:
        if int(iyilesen_degisim[i]) <= -10000:    sh = 0.5
        elif int(iyilesen_degisim[i]) <= -1000:   sh = 0.4
        elif int(iyilesen_degisim[i]) <= -100:    sh = 0.33
        else:    sh = 0.25
        plt.text(i-sh, iyilesen_degisim[i]-2500, int(iyilesen_degisim[i]), fontsize=14, color='#880000')
plt.axhline(0, color='black')
plt.title('Covid-19 - Türkiye\'de İyileşen Sayısı Değişimi (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, color='#555555', fontweight='bold')
plt.ylabel('İyileşen Sayısı Değişim', fontsize=16, color='#555555', fontweight='bold')
plt.grid(visible=True, color='#cccccc')
plt.show()

# %% [markdown]
# Son 20 günün iyileşen sayısı değişiminde, en fazla artış **15 Şubat 2022**'de **27737** ile gerçekleşirken; en fazla düşüş **15707** ile **27 Şubat 2022**'de görülmüştür.

# %% [markdown]
# ## **Son 20 Gün İçindeki Günlük İyileşen Sayısının Vaka Sayısına Oranı**

# %%
index = covid19TR['İyileşen Artış'][-20:].index
iyilesen_artis = covid19TR['İyileşen Artış'][-20:]
gunluk_vaka = covid19TR['Günlük Vaka'][-20:]
oranlar = iyilesen_artis / gunluk_vaka
colors = []
for i in range(20):
    if oranlar[i] < 1.0:    colors.append('#cc0000')
    else:    colors.append('#009900')
plt.figure(figsize=(15.5,5))
plt.axis([-0.5, 19.5, min(oranlar)*0.92, max(oranlar)*1.1])
plt.axhline(1.0, color='black', zorder=1)
plt.scatter(index, oranlar, marker="o", s=1200, color=colors, zorder=2)
for i in range(20):
    plt.text(i-0.32, oranlar[i]-0.012, "{:.2f}".format(round(oranlar[i], 2)), color='white', fontsize=15)
plt.title("Covid-19 - Türkiye\'de Günlük İyileşen Sayısının Vaka Sayısına Oranı (Son 20 Gün)", 
          fontsize=21, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, fontweight='bold')
plt.ylabel('ORAN', fontsize=16, fontweight='bold')
plt.xticks(rotation=80, fontsize=12)
plt.yticks(fontsize=14)
plt.grid(visible=True, color='#cccccc', zorder=0)
plt.show()

# %% [markdown]
# Son 20 gün içindeki günlük iyileşen sayısının günlük vaka sayısına oranlara _rasyonel şekilde_ baktığımızda, 9-14 Şubat 2022 tarihlerinde **1**'in altında çıkan bu oranlar, 15 Şubat 2022'den sonra **hep 1'in üstüne** çıkmıştır! Bu günler içinde en yüksek oran **1.4** ile 27 Şubat 2022'de görülmüştür; başka bir deyişle ilgili günde iyileşen sayıları vaka sayılarından **%40** daha yüksek olmuştur.

# %% [markdown]
# ## **Son 20 Günün Toplam Aktif Vaka Sayıları**

# %%
covid19TR['Toplam Aktif Vaka'] = covid19TR['Toplam Vaka'] - covid19TR['Toplam Vefat'] - covid19TR['Toplam İyileşen']
toplam_aktif_vaka_son20 = covid19TR['Toplam Aktif Vaka'][-20:]
slp, intcp = np.polyfit(list(range(20)), toplam_aktif_vaka_son20, 1)
plt.figure(figsize=(15,6))
plt.bar(covid19TR.index[-20:], toplam_aktif_vaka_son20, color='orange', width=0.75)
plt.axis([-0.5, 19.5, toplam_aktif_vaka_son20.min()*0.95, toplam_aktif_vaka_son20.max()*1.04])
for i in range(len(covid19TR)-20,len(covid19TR)):
    plt.text(i-(len(covid19TR)-19.5), covid19TR.iloc[i,22]+3000, "{:6}".format(int(covid19TR.iloc[i,22])),
             fontsize=12, color='#aa3300')
    if covid19TR.iloc[i,19]/covid19TR.iloc[i,9]*100 >= 10:    sh = 19.6
    else:    sh = 19.68
    plt.text(i-(len(covid19TR)-sh), covid19TR.iloc[i,22]-12000, 
             "{:3.2f}".format(round(covid19TR.iloc[i,22]/covid19TR.iloc[i,9]*100, 2)), fontsize=14, color='#aa3300')
plt.plot([0,19],[intcp,intcp+(slp*19)], linewidth=15, alpha=0.4, color='#ff7700')
plt.xticks(rotation=75, fontsize=12)
plt.yticks(fontsize=13, color='#ff5500')
plt.title('Covid-19 - Türkiye\'de Toplam Aktif Vaka Sayıları (Son 20 Gün)', fontsize=24, fontweight='bold')
plt.xlabel('Tarih', fontsize=16, fontweight='bold')
plt.ylabel('Aktif Hasta Sayıları\nAktif Vaka / Toplam Vaka Oranı (%)', fontsize=16, color='#aa3300', fontweight='bold')
plt.grid(visible=True, color='#f3d0ad')
plt.show()

# %% [markdown]
# Yukarıda incelediğimiz tüm günlük vaka, vefat ve iyileşen sayıları analizlerinden sonra hepsini beraber düşündüğümüzde, 14 Şubat 2022'de **833789**'a kadar yükselmiş olan toplam aktif vaka sayısı, bu tarihten sonra **düşüş eğilimine geçerek** en son 28 Şubat 2022'de **628778**'e doğru gerilemiştir.
#
# Toplam vaka oranlarına baktığımızda yine çok benzer bir değişime rastlamaktayız. Öyle ki, 12 Şubat 2022'de **%6.46**'ya çıkmış olup, devamında sürekli gerileyerek **%4.46**'a kadar indiğini görmekteyiz!

# %% [markdown]
# ### **Son 240 Güne Dair Günlük Test, Vaka, Vefat ve İyileşen Sayılarının İstatistikleri ve Dağılımları**

# %%
round(covid19TR[['Test Artış', 'Günlük Vaka', 'Vefat Artış' , 'İyileşen Artış']][-240:].describe(), 2)
# Out:
#        Test Artış  Günlük Vaka  Vefat Artış  İyileşen Artış
# count      240.00       240.00       240.00          240.00
# mean    344535.59     36037.87       185.71        33564.44
# std      65035.36     26331.07        63.46        26680.90
# min     184462.00      4418.00        35.00         4152.00
# 25%     297142.25     20315.00       157.00        16648.75
# 50%     354482.50     25694.50       196.00        25613.50
# 75%     366982.75     36695.75       228.00        32254.00
# max     468152.00    111157.00       309.00       104409.00

# %%
plt.figure(figsize=(13.5,7))
plt.subplot(4,1,1)
sns.boxplot(x='Test Artış', data=covid19TR[-240:], color='#ff8800', fliersize=1, linewidth=3)
sns.swarmplot(x='Test Artış', data=covid19TR[-240:], color='#ffba42', alpha=0.8, size=4)
plt.title('Günlük Test (Son 240 Gün)', fontsize=20, fontweight='bold')
plt.grid(color='#aaaaaa')
plt.subplot(4,1,2)
sns.boxplot(x='Günlük Vaka', data=covid19TR[-240:], color='#bb0000', fliersize=1, linewidth=3)
sns.swarmplot(x='Günlük Vaka', data=covid19TR[-240:], color='#ee0000', alpha=0.8, size=4)
plt.title('Günlük Vaka (Son 240 Gün)', fontsize=20, fontweight='bold')
plt.grid(color='#aaaaaa')
plt.subplot(4,1,3)
sns.boxplot(x='Vefat Artış', data=covid19TR[-240:], color='#666666', fliersize=1, linewidth=3)
sns.swarmplot(x='Vefat Artış', data=covid19TR[-240:], color='#999999', alpha=0.8, size=4)
plt.title('Günlük Vefat (Son 240 Gün)', fontsize=20, fontweight='bold')
plt.grid(color='#aaaaaa')
plt.subplot(4,1,4)
sns.boxplot(x='İyileşen Artış', data=covid19TR[-240:], color='#00aa00', fliersize=1, linewidth=3)
sns.swarmplot(x='İyileşen Artış', data=covid19TR[-240:], color='#00dd00', alpha=0.8, size=4)
plt.title('Günlük İyileşen (Son 240 Gün)', fontsize=20, fontweight='bold')
plt.grid(color='#aaaaaa')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Son 240 Güne Dair Vaka, Vefat & İyileşen Sayısı Değişimi İstatistikleri ve Dağılımları**

# %%
round(covid19TR[['Vaka +/-', 'Vefat +/-', 'İyileşen +/-']][-240:].describe(),2)
# Out:
#        Vaka +/-  Vefat +/-  İyileşen +/-
# count    240.00     240.00        240.00
# mean     248.91       0.70        299.66
# std     4190.97      19.67       4027.39
# min   -12982.00     -45.00     -15707.00
# 25%    -1240.75     -13.00      -1364.25
# 50%      -92.00      -2.00        205.50
# 75%     1587.50      13.25       1522.25
# max    18098.00      54.00      27737.00

# %%
plt.figure(figsize=(12,6.5))
plt.subplot(3,1,1)
sns.boxplot(x='Vaka +/-', data=covid19TR[-240:], color='#bb0000', fliersize=1, linewidth=3)
sns.swarmplot(x='Vaka +/-', data=covid19TR[-240:], color='#ee0000', alpha=0.8, size=4)
plt.grid(color='#bbbbbb')
plt.title('Vaka Sayısı Değişimi (Son 240 Gün)', fontsize=20, fontweight='bold')
plt.subplot(3,1,2)
sns.boxplot(x='Vefat +/-', data=covid19TR[-240:], color='#666666', fliersize=1, linewidth=3)
sns.swarmplot(x='Vefat +/-', data=covid19TR[-240:], color='#999999', alpha=0.8, size=4)
plt.grid(color='#bbbbbb')
plt.title('Vefat Sayısı Değişimi (Son 240 Gün)', fontsize=20, fontweight='bold')
plt.subplot(3,1,3)
sns.boxplot(x='İyileşen +/-', data=covid19TR[-240:], color='#00bb00', fliersize=1, linewidth=3)
sns.swarmplot(x='İyileşen +/-', data=covid19TR[-240:], color='#00ff00', alpha=0.8, size=4)
plt.grid(color='#bbbbbb')
plt.title('İyileşen Sayısı Değişimi (Son 240 Gün)', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# _ÖNEMLİ!: 4 Temmuz 2021'den itibaren gösterilmeye başlanan yeni Günlük Covid-19 Tablosu ile artık Hasta Sayısı verisi paylaşılmadığından ilgili çubuk yukarıdaki iki grafikte yer almamaktadır!_

# %% [markdown]
# ### **25 Kasım 2020 Sonrası Günlük Vaka, Vefat ve İyileşen Sayılarının Birbirleriyle İlişkileri ve Katsayıları**

# %%
gunluk_vaka_25kas2020_sonra = covid19TR['Günlük Vaka'][259:]
vefat_artis_25kas2020_sonra = covid19TR['Vefat Artış'][259:]
iyilesen_artis_12ara2020_haric = np.concatenate((covid19TR['İyileşen Artış'][259:276].values,
                                                 covid19TR['İyileşen Artış'][277:].values))
slp1, intcp1 = np.polyfit(gunluk_vaka_25kas2020_sonra, vefat_artis_25kas2020_sonra, 1)
x1 = [0, gunluk_vaka_25kas2020_sonra.max()]
y1 = [intcp1+x1[0], intcp1+(slp1*x1[1])]
plt.figure(figsize=(14,12))
plt.subplot(2, 2, 1)
plt.title('25.11.2020 Sonrası Günlük Vaka/Vefat Sayıları İlişkisi', fontsize=16, fontweight='bold')
plt.scatter(gunluk_vaka_25kas2020_sonra, vefat_artis_25kas2020_sonra, marker='d', s=70, color='#770000', alpha=0.4)
plt.plot(x1, y1, alpha=0.5, linewidth=6, color='#990000')
plt.text(gunluk_vaka_25kas2020_sonra.min()+60000, vefat_artis_25kas2020_sonra.max()-10,
         "Korelasyon: " + str(round(np.corrcoef(gunluk_vaka_25kas2020_sonra, vefat_artis_25kas2020_sonra)[0,1], 6)), 
         fontsize=13, fontweight='bold')
plt.xlabel('Günlük Vaka Sayıları', fontsize=14, fontweight='bold')
plt.ylabel('Günlük Vefat Sayıları', fontsize=14, fontweight='bold')
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.grid(visible=True, color='#ecc9bf')
slp2, intcp2 = np.polyfit(gunluk_vaka_25kas2020_sonra.drop('2020-12-12'), iyilesen_artis_12ara2020_haric, 1)
x2 = [gunluk_vaka_25kas2020_sonra.min(), gunluk_vaka_25kas2020_sonra.max()]
y2 = [intcp2, intcp2+(slp2*(x2[1]))]
plt.subplot(2, 2, 2)
plt.title('25.11.2020 Sonrası Günlük Vaka/İyileşen Sayıları İlişkisi', fontsize=16, fontweight='bold')
plt.scatter(gunluk_vaka_25kas2020_sonra.drop('2020-12-12'), iyilesen_artis_12ara2020_haric, 
            marker='d', s=70, color='#007700', alpha=0.4)
plt.text(gunluk_vaka_25kas2020_sonra.max()-40000, iyilesen_artis_12ara2020_haric.min()-500,
         "Korelasyon: " + str(round(np.corrcoef(gunluk_vaka_25kas2020_sonra.drop('2020-12-12'),
                                                iyilesen_artis_12ara2020_haric)[0,1], 6)), fontsize=13, fontweight='bold')
plt.plot(x2, y2, alpha=0.5, linewidth=6, color='#009900')
plt.xlabel('Günlük Vaka Sayıları', fontsize=14, fontweight='bold')
plt.ylabel('Günlük İyileşen Sayıları', fontsize=14, fontweight='bold')
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.grid(visible=True, color='#84ec95')
slp3, intcp3 = np.polyfit(vefat_artis_25kas2020_sonra.drop('2020-12-12'), iyilesen_artis_12ara2020_haric, 1)
x3 = [0, vefat_artis_25kas2020_sonra.max()]
y3 = [intcp3+x3[0], intcp3+(slp3*x3[1])]
plt.subplot(2, 2, 3)
plt.title('25.11.2020 Sonrası Günlük Vefat/İyileşen Sayıları İlişkisi', fontsize=16, fontweight='bold')
plt.scatter(vefat_artis_25kas2020_sonra.drop('2020-12-12'), iyilesen_artis_12ara2020_haric, 
            marker='d', s=70, color='#515296', alpha=0.4)
plt.plot(x3, y3, alpha=0.5, linewidth=6, color='#515296')
plt.text(vefat_artis_25kas2020_sonra.min()-30, iyilesen_artis_12ara2020_haric.max()-4000,
         "Korelasyon: " + str(round(np.corrcoef(vefat_artis_25kas2020_sonra.drop('2020-12-12'), 
                                                iyilesen_artis_12ara2020_haric)[0,1], 6)), fontsize=13, fontweight='bold')
plt.xlabel('Günlük Vefat Sayıları', fontsize=14, fontweight='bold')
plt.ylabel('Günlük İyileşen Sayıları', fontsize=14, fontweight='bold')
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.grid(visible=True, color='#cfc8f7')
plt.tight_layout()
plt.show()

# %% [markdown]
# _**ÖNEMLİ 1:** 12 Aralık 2020'ye ait iyileşen artış sayısının 1 milyonun üzerinde çıkmasından dolayı tutarlılık açısından ilgili grafiklere dahil edilmemiştir!_
#
# _**ÖNEMLİ 2:** 4 Temmuz 2021'den itibaren gösterilmeye başlanan yeni Günlük Covid-19 Tablosu ile artık Hasta Sayısı verisi paylaşılmadığından ilgili ilişki grafikleri yer almamaktadır!_

# %% [markdown]
# ### Test, Vaka, Vefat ve İyileşen Artışlarının Aylık Toplamları

# %%
analiz_sutunlar = ['Test Artış', 'Günlük Vaka', 'Vefat Artış', 'İyileşen Artış',
                   'Test +/-', 'Vaka +/-', 'Vefat +/-', 'İyileşen +/-']
covid19TR = covid19TR.reset_index()
covid19TR['Tarih'] = pd.to_datetime(covid19TR['Tarih'])
covid19TR_aylik_toplam = covid19TR.resample('M', on='Tarih')[analiz_sutunlar[:4]].sum()
covid19TR_aylik_toplam.columns = ['Toplam Test', 'Toplam Vaka', 'Toplam Vefat', 'Toplam İyileşen']
covid19TR_aylik_toplam
# Out:
#             Toplam Test  Toplam Vaka  Toplam Vefat  Toplam İyileşen
# Tarih
# 2020-03-31        92403            0           214              243
# 2020-04-30       941214            0          2960            48643
# 2020-05-31      1005577            0          1366            79087
# 2020-06-30      1342456            0           591            45138
# 2020-07-31      1419173            0           560            41424
# 2020-08-31      2337669            0           679            30391
# 2020-09-30      3241769            0          1825            34823
# 2020-10-31      3621553            0          2057            44222
# 2020-11-30      4590478       177931          3494            80756
# 2020-12-31      5912275       777004          7135          1695923
# 2021-01-31      5126855       268811          5112           261765
# 2021-02-28      3543594       224125          2576           209819
# 2021-03-31      5403041       615594          2968           441992
# 2021-04-30      8683942      1503409          8594          1309671
# 2021-05-31      6877310       428824          7396           790727
# 2021-06-30      6647666       176248          2205           179661
# 2021-07-31      7081876       301393          1600           160075
# 2021-08-31      8568614       661286          5378           382857
# 2021-09-30      9873289       765739          7344           778691
# 2021-10-31     10986445       878918          6557           874217
# 2021-11-30     10716229       762600          6231           836256
# 2021-12-31     11012714       686962          5519           736981
# 2022-01-31     12613097      2137332          5055          1847847
# 2022-02-28     12504520      2469574          7029          2455025

# %% [markdown]
# _Buradaki Toplam Vaka sayılarının aylık toplamlarının 25 Kasım 2020 ve sonrasına ait olduğu unutulmamalıdır._

# %% [markdown]
# ### Aynı Sütunların ve Değişimlerinin Aylık Ortalamaları

# %%
covid19TR_aylik_ortalama = covid19TR.resample('M', on='Tarih')[analiz_sutunlar].mean().fillna(0)
round(covid19TR_aylik_ortalama, 2)
# Out:
#             Test Artış  Günlük Vaka  Vefat Artış  İyileşen Artış  Test +/-  \
# Tarih
# 2020-03-31     4400.14         0.00        10.19           11.57    734.38
# 2020-04-30    31373.80         0.00        98.67         1621.43    886.07
# 2020-05-31    32437.97         0.00        44.06         2551.19   -206.58
# 2020-06-30    44748.53         0.00        19.70         1504.60    496.40
# 2020-07-31    45779.77         0.00        18.06         1336.26   -129.03
# 2020-08-31    75408.68         0.00        21.90          980.35   2051.94
# 2020-09-30   108058.97         0.00        60.83         1160.77     66.53
# 2020-10-31   116824.29         0.00        66.35         1426.52    387.45
# 2020-11-30   153015.93      5931.03       116.47         2691.87   1751.57
# 2020-12-31   190718.55     25064.65       230.16        54707.19     50.35
# 2021-01-31   165382.42      8671.32       164.90         8444.03  -1348.35
# 2021-02-28   126556.93      8004.46        92.00         7493.54   -956.39
# 2021-03-31   174291.65     19857.87        95.74        14257.81   4205.58
# 2021-04-30   289464.73     50113.63       286.47        43655.70    842.50
# 2021-05-31   221848.71     13833.03       238.58        25507.32  -1478.26
# 2021-06-30   221588.87      5874.93        73.50         5988.70    290.07
# 2021-07-31   228447.61      9722.35        51.61         5163.71   1001.06
# 2021-08-31   276406.90     21331.81       173.48        12350.23   1224.87
# 2021-09-30   329109.63     25524.63       244.80        25956.37   2022.87
# 2021-10-31   354401.45     28352.19       211.52        28200.55   -338.42
# 2021-11-30   357207.63     25420.00       207.70        27875.20    401.93
# 2021-12-31   355248.84     22160.06       178.03        23773.58    422.45
# 2022-01-31   406874.10     68946.19       163.06        59607.97   2032.16
# 2022-02-28   446590.00     88199.07       251.04        87679.46   -895.64
#
#             Vaka +/-  Vefat +/-  İyileşen +/-
# Tarih
# 2020-03-31      0.00       2.19          3.86
# 2020-04-30      0.00       1.57        159.43
# 2020-05-31      0.00      -2.19       -125.00
# 2020-06-30      0.00      -0.30         10.43
# 2020-07-31      0.00       0.03         -9.87
# 2020-08-31      0.00       0.87          2.94
# 2020-09-30      0.00       0.70          5.27
# 2020-10-31      0.00       0.32          8.42
# 2020-11-30   1040.63       3.77         99.30
# 2020-12-31   -543.19       1.65        565.68
# 2021-01-31   -252.19      -3.58       -484.35
# 2021-02-28     66.50      -2.21        -17.68
# 2021-03-31    996.06       2.77        409.10
# 2021-04-30   -247.03       8.07       1633.00
# 2021-05-31   -819.29      -8.81      -1890.35
# 2021-06-30    -33.23      -2.53        -79.70
# 2021-07-31    543.10       1.10        -67.23
# 2021-08-31    -14.16       5.58        290.29
# 2021-09-30    240.37      -1.20        600.43
# 2021-10-31   -166.32      -0.48       -191.74
# 2021-11-30     42.27       0.20        -55.90
# 2021-12-31    502.26      -1.42        -17.10
# 2022-01-31   1692.74       0.61       2240.97
# 2022-02-28  -1035.21       1.11       -593.07

# %% [markdown]
# _Buradaki Günlük Vaka sayılarının aylık ortalamaları ve değişimlerinin 25 Kasım 2020 ve sonrasına ait olduğu unutulmamalıdır._

# %% [markdown]
# ## SON YORUMLAR
#
# **Yukarıdaki veri analizlerinde tüm bu rakamlar ve görseller gösteriyor ki Türkiye'de iki yıla yakın süren Koronavirüs (Covid-19) ile mücadelede genel riskin Omicron varyantının etkisiyle önceki haftalara göre biraz azalsa da genel olarak HALA DEVAM ETTİĞİ görülmektedir!**
#
# **AŞILAMANIN günden güne devam etmesiyle birlikte toplumumuzda daha güçlü bağışıklık sağlanmaktadır. Hatırlatma dozlarının yanında özellikle de 2. doz Biontech'in üzerinden 3 aydan fazla süre geçen vatandaşlar için 3. doz imkanının getirilmesi ile ileride vaka ve vefat sayılarına olumlu yönde yansıması beklentisi olmasına karşın Omicron varyantından dolayı bunun kısa vadede gerçekleşemeyeceği halen açık bir şekilde görülmektedir! Pozitif çıkan PCR testlerin ve vefatların büyük oranda aşısız veya aşısı eksik olan insanlardan kaynaklandığını haberlerde izlemekteyiz ki aşıların virüsün Delta varyantına ve ülkemiz dahil dünyanın birçok yerinde baskın şekilde seyretmeye devam eden Omicron varyantına karşı KORUYUCU etkisinin olduğunun önemi gözler önümüze serilmektedir!**
#
# **HER ZAMAN SÖYLEDİĞİMİZİ BURADAN TEKRAR EDELİM... Virüsün yayılmasına engel olmak için - üç doz aşımız olsa bile - hala virüs yokmuş gibi davranmamaya; kendimizi, sevdiklerimizi ve etrafımızdaki insanları önemseyerek tedbirlerimizi almaya devam edelim. Aşı sıramız gelene kadar gerekli görüldüğünde PCR testlerini yaptırmaya ve erişim hakkımız tanınmışsa bir an önce aşı randevumuzu almaya ve günü geldiğine aşımızı olmaya özen gösterelim. Eksik ya da tam aşı olsak dahi maske takmaya, dezenfaktan kullanmaya, hijyenimize dikkat etmeye, kalabalık ortamlarda fazla kalmamaya ve açık/kapalı alanlarda sosyal mesafeyi korumaya özen gösterelim! Bunlarla beraber güvenilir kaynaklardan, T.C. Sağlık Bakanlığı'dan, Türkiye'den ve Dünya'dan Koronavirüs ile ilgili en son haberleri edinmeye çalışalım!**
#
# ## Koronavirüsü tamamen yendiğimiz günlerde buluşmak dileğiyle...
